# %%
import mysql.connector as sql
import pandas as pd

db_connection=sql.connect(host='localhost',database='ai',user='root',password='root')
#db_cursor=db_connection.cursor()
#db_cursor.execute('SELECT * FROM train')

#table_rows=db_cursor.fetchall()

#df=pd.DataFrame(table_rows)
#df

query = "SELECT * FROM train"
df_mysql = pd.read_sql(query, con = db_connection)
df_mysql
# print(db_connection)
# Out:
# C:\Users\91981\AppData\Local\Temp\ipykernel_14596\1162477172.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql = pd.read_sql(query, con = db_connection)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 709          886         0       3
# 710          887         0       2
# 711          888         1       1
# 712          890         1       1
# 713          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# ...

# %% [markdown]
# # DISPLAY TOP 5 ROWS OF THE DATASET

# %%
df_mysql.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500              S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250              S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500              S

# %% [markdown]
# # CHECK LAST 3 ROWS OF THE DATASET

# %%
df_mysql.tail(3)

# %% [markdown]
# # FIND SHAPE OF OUR DATASET(NUMBER OF ROWS & NUMBER OF COLUMNS)

# %%
df_mysql.shape
print("No of rows: ",df_mysql.shape[0])
print("No of rows: ",df_mysql.shape[1])
# Out:
# No of rows:  714
# No of rows:  12

# %% [markdown]
# # GET INFORMATION ABOUT OUR DATASET LIKE TOTAL NUMBER ROWS,TOTAL NUMBER OF COLUMNS,DATATYPE OF EACH COLUMN AND MEMORY REQUIREDMENT

# %%
df_mysql.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  714 non-null    int64
#  1   Survived     714 non-null    int64
#  2   Pclass       714 non-null    int64
#  3   Name         714 non-null    object
#  4   Sex          714 non-null    object
#  5   Age          714 non-null    int64
#  6   SibSp        714 non-null    int64
#  7   Parch        714 non-null    int64
#  8   Ticket       714 non-null    object
#  9   Fare         714 non-null    float64
#  10  Cabin        714 non-null    object
#  11  Embarked     714 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 67.1+ KB

# %% [markdown]
# # GET OVERALL STATISTICS ABOUT THE DATAFRAME

# %%
df_mysql.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   714.000000  714.000000  714.000000  714.000000  714.000000
# mean    448.582633    0.406162    2.236695   29.712885    0.512605
# std     259.119524    0.491460    0.838250   14.529273    0.929783
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     222.250000    0.000000    1.000000   20.250000    0.000000
# 50%     445.000000    0.000000    2.000000   28.000000    0.000000
# 75%     677.750000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    5.000000
#
#             Parch        Fare
# count  714.000000  714.000000
# mean     0.431373   34.694514
# std      0.853289   52.918930
# min      0.000000    0.000000
# 25%      0.000000    8.050000
# 50%      0.000000   15.741700
# 75%      1.000000   33.375000
# max      6.000000  512.329200

# %% [markdown]
# # DATA FILTERING

# %% [markdown]
# # CHECK NULL VALUES IN THE DATASET

# %%
df_mysql.isnull().sum(axis=0)*100/len(df_mysql)
# Out:
# PassengerId    0.0
# Survived       0.0
# Pclass         0.0
# Name           0.0
# Sex            0.0
# Age            0.0
# SibSp          0.0
# Parch          0.0
# Ticket         0.0
# Fare           0.0
# Cabin          0.0
# Embarked       0.0
# dtype: float64

# %% [markdown]
# # DROP THE COLUMN

# %%
data=df_mysql.drop(['Embarked'],axis=1)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 709          886         0       3
# 710          887         0       2
# 711          888         1       1
# 712          890         1       1
# 713          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %% [markdown]
# # CATEGORICAL DATA ENCODING

# %%
df_mysql['Sex'].unique()
df_mysql['Gender']=df_mysql['Sex'].map({'male':1,'female':0})
df_mysql.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender
# 0      0         A/5 21171   7.2500              S       1
# 1      0          PC 17599  71.2833   C85        C       0
# 2      0  STON/O2. 3101282   7.9250              S       0
# 3      0            113803  53.1000  C123        S       0
# ...

# %%
import pandas as pd
pd.get_dummies(df_mysql,columns=['Embarked'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 709          886         0       3
# 710          887         0       2
# 711          888         1       1
# 712          890         1       1
# 713          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %% [markdown]
# # WHAT IS UNIVARIATE ANALYSIS

# %%
df_mysql.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Gender'],
#       dtype='object')

# %% [markdown]
# # HOW MANY PEOPLE SURVIVED AND HOW MANY DIED PLOT ON GRAPH

# %%
df_mysql
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 709          886         0       3
# 710          887         0       2
# 711          888         1       1
# 712          890         1       1
# 713          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
data1=len(df_mysql[df_mysql['Survived']==1])
print(data1)
data2=len(df_mysql[df_mysql['Survived']==0])
print(data2)
# Out:
# 290
# 424

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df_mysql['Survived'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # HOW MANY PASSENGERS WERE IN FIRST CLASS,SECOND CLASS AND THIRD CLASS PLOT THOSE FIGURES ON GRAPH

# %%
df_mysql['Pclass'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # NUMBER  OF MALE AND FEMALE PASSANGERS

# %%
data1=len(df_mysql[df_mysql['Sex']=='male'])
print("number of males:",data1)
data2=len(df_mysql[df_mysql['Sex']=='female'])
print("Number of females: ",data2)
# Out:
# number of males: 453
# Number of females:  261

# %%
df_mysql['Sex'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # BIVARIANT ANALSIS

# %%
import seaborn as sns
sns.boxplot(x='Sex',y='Age',data=df_mysql)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# # HOW HAS BETTER CANCE OF SURVIVAL MALE OR FEMALE

# %%
df_mysql.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.754789
# male      0.205298
# Name: Survived, dtype: float64

# %%
sns.boxplot(x='Sex',y='Survived',data=df_mysql)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %% [markdown]
# # WHICH PASSENGER CLASS HAS BETTER CHANCE OF SURVIVAL(FIRST,SECOND,OR THIRD CLASS)?

# %%
df_mysql.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.655914
# 2    0.479769
# 3    0.239437
# Name: Survived, dtype: float64
